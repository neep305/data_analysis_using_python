# %%
import unicodecsv

# %%
def read_csv(filename):
    with open(filename,'rb') as f:
        reader = unicodecsv.DictReader(f)
        return list(reader)

# %% [markdown]
# ### Importing data of enrollments.csv

# %%
enrollments = read_csv('./csv/enrollments.csv')

# %%
type(enrollments)
# Out:
# list

# %%
enrollments[0]
# Out:
# {'account_key': '448',
#  'cancel_date': '2015-01-14',
#  'days_to_cancel': '65',
#  'is_canceled': 'True',
#  'is_udacity': 'True',
#  'join_date': '2014-11-10',
#  'status': 'canceled'}

# %% [markdown]
# ### Importing data of daily engagement

# %%
engagements = read_csv('./csv/daily_engagement.csv')
engagements[0]
# Out:
# {'acct': '0',
#  'lessons_completed': '0.0',
#  'num_courses_visited': '1.0',
#  'projects_completed': '0.0',
#  'total_minutes_visited': '11.6793745',
#  'utc_date': '2015-01-09'}

# %%
project_submissions = read_csv('./csv/project_submissions.csv')
project_submissions[0]
# Out:
# OrderedDict([('creation_date', '2015-01-14'),
#              ('completion_date', '2015-01-16'),
#              ('assigned_rating', 'UNGRADED'),
#              ('account_key', '256'),
#              ('lesson_key', '3176718735'),
#              ('processing_state', 'EVALUATED')])

# %% [markdown]
# ### datatime library 활용하기

# %%
from datetime import datetime as dt

def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
def parse_maybe_int(i):
    if i == '':
        return None
    else:
        return int(i)

# %%
for enrollment in enrollments:
    
    enrollment['cancel_date'] = parse_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['join_date'] = parse_date(enrollment['join_date'])
    
enrollments[0]
# Out:
# OrderedDict([('account_key', '448'),
#              ('status', 'canceled'),
#              ('join_date', datetime.datetime(2014, 11, 10, 0, 0)),
#              ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)),
#              ('days_to_cancel', 65),
#              ('is_udacity', True),
#              ('is_canceled', True)])

# %%
daily_engagement = read_csv('./csv/daily_engagement.csv')

# %%
daily_engagement[0]
# Out:
# {'acct': '0',
#  'lessons_completed': '0.0',
#  'num_courses_visited': '1.0',
#  'projects_completed': '0.0',
#  'total_minutes_visited': '11.6793745',
#  'utc_date': '2015-01-09'}

# %%
# Clean up the data types in the engagement table
for engagement_record in daily_engagement:
    engagement_record['lessons_completed'] = int(float(engagement_record['lessons_completed']))

# %%
for submission in project_submissions:
    submission['creation_date'] = parse_date(submission['creation_date'])
    submission['completion_date'] = parse_date(submission['completion_date'])
    
project_submissions[0]
# Out:
# OrderedDict([('creation_date', datetime.datetime(2015, 1, 14, 0, 0)),
#              ('completion_date', datetime.datetime(2015, 1, 16, 0, 0)),
#              ('assigned_rating', 'UNGRADED'),
#              ('account_key', '256'),
#              ('lesson_key', '3176718735'),
#              ('processing_state', 'EVALUATED')])

# %%
project_submissions
# Out:
# [OrderedDict([('creation_date', datetime.datetime(2015, 1, 14, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 16, 0, 0)),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '256'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 13, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '256'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 20, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 20, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '256'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 13, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '434'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 17, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 3, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '434'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 6, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 6, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 26, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 28, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 31, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 2, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '381'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 29, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '381'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 29, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 7, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 13, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '381'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 6, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 6, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 5, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '381'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 13, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 23, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '378'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 19, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 2, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '23'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 11, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '23'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 3, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '23'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 8, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '23'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2014, 12, 24, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 7, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '23'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 25, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '23'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 26, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 11, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '23'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 6, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 19, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '23'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 23, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 31, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 21, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 11, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 18, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 18, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 10, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 20, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 14, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 15, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 12, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 31, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 4, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 22, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 23, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 12, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 29, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '616'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 26, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 26, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 9, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '616'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2014, 12, 31, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 15, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '223'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 18, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '223'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '152'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 9, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 19, 0, 0)),
#               ('assigned_rating', 'DISTINCTION'),
#               ('account_key', '152'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 9, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '152'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 12, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 12, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 6, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 6, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 29, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 3, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 4, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 11, 0, 0)),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '1098'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 11, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 26, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1098'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 26, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1098'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 25, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 28, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '273'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 3, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 17, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '273'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 26, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '273'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 24, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 7, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '273'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 20, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '273'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 25, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 25, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '599'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 3, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 3, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '599'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2014, 12, 14, 0, 0)),
#               ('completion_date', datetime.datetime(2014, 12, 23, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '639'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 13, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 26, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '639'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 19, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 19, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '324'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 12, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '324'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 26, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 27, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '324'),
#               ('lesson_key', '4582204201'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 19, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 19, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '324'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 10, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 9, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 9, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 18, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '439'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 3, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 7, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '439'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 9, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 9, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 22, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 27, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '439'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 11, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 29, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 6, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 6, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '439'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 12, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '608'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 12, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '608'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '608'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 16, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 3, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '30'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '30'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 16, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 19, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '30'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 17, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '30'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 10, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '168'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 30, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '168'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 4, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 4, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '168'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '168'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 26, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 27, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '224'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 15, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '224'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 25, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 26, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '224'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 25, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 25, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '224'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 25, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '224'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 4, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 7, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '224'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 19, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '224'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 11, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '224'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 2, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 3, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1206'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 24, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 24, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '575'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 19, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 20, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '575'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 20, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 20, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '575'),
#               ('lesson_key', '4582204201'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 10, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '575'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 16, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 17, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 20, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 16, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 6, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 13, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 25, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 26, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 16, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 16, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 14, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 30, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 1, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '641'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 13, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 13, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 23, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 23, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 8, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 8, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '641'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '156'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 8, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '156'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 26, 0, 0)),
#               ('assigned_rating', 'DISTINCTION'),
#               ('account_key', '156'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 9, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 10, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '156'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 9, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 18, 0, 0)),
#               ('assigned_rating', 'DISTINCTION'),
#               ('account_key', '156'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 2, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 3, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '232'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 8, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '232'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 27, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 27, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '232'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 5, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '232'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 24, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 24, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '484'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 23, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 24, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 13, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 13, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 1, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 7, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 22, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 23, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 14, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 14, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 14, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 14, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 11, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '484'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 2, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 3, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 13, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 13, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '484'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 3, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 3, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '484'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 29, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1224'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 10, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 11, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 30, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 30, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '1'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 28, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '1'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2014, 12, 30, 0, 0)),
#               ('completion_date', datetime.datetime(2014, 12, 31, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '611'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2014, 12, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 1, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '611'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 18, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '611'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 1, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 3, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '189'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 29, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '189'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 20, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '189'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 27, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 27, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 6, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 6, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '491'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 26, 0, 0)),
# ...
#               ('account_key', '525'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 20, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 27, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '525'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 26, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 7, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '525'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 1, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 5, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '525'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 16, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 18, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 18, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 18, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 20, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 17, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 8, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 8, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 1, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 7, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '4110338963'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 14, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 15, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 7, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 10, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 15, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 16, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 30, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 20, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 18, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 19, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '4582204201'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 30, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 4, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '125'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 19, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 21, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '125'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 22, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 24, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 13, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 20, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 29, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 1, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 16, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 28, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 27, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 27, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 14, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 17, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 13, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 24, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 24, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3184238632'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 19, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 20, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 28, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 15, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 13, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 13, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '570'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 17, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 31, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '570'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 16, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 16, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 7, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 13, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '634'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 2, 1, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 2, 16, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 15, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 13, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 31, 0, 0)),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '634'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 29, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 4, 7, 0, 0)),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '634'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 27, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 28, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '21'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 21, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 21, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '21'),
#               ('lesson_key', '4582204201'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 5, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '21'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 5, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 5, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '21'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 7, 17, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 7, 18, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '21'),
#               ('lesson_key', '4576183932'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 26, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 5, 26, 0, 0)),
#               ('assigned_rating', 'UNGRADED'),
#               ('account_key', '369'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 8, 18, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 8, 19, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '369'),
#               ('lesson_key', '3174288624'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 6, 16, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 16, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '369'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 5, 26, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 6, 3, 0, 0)),
#               ('assigned_rating', 'INCOMPLETE'),
#               ('account_key', '369'),
#               ('lesson_key', '3165188753'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 3, 9, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 3, 26, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '369'),
#               ('lesson_key', '3168208620'),
#               ('processing_state', 'EVALUATED')]),
#  OrderedDict([('creation_date', datetime.datetime(2015, 1, 12, 0, 0)),
#               ('completion_date', datetime.datetime(2015, 1, 23, 0, 0)),
#               ('assigned_rating', 'PASSED'),
#               ('account_key', '369'),
#               ('lesson_key', '3176718735'),
#               ('processing_state', 'EVALUATED')]),
#  ...]

# %%
len(enrollments)
# Out:
# 1640

# %%
unique_enrolled_students = set() 

for enrollment in enrollments:
    unique_enrolled_students.add(enrollment['account_key'])

len(unique_enrolled_students)
# Out:
# 1302

# %%
unique_engagement_students = set()

for enrollment in daily_engagement:
    unique_engagement_students.add(enrollment['acct'])

len(unique_engagement_students)

# %%
len(project_submissions)
# Out:
# 3642

# %%
unique_project_submitters = set()

for submission in project_submissions:
    unique_project_submitters.add(submission['account_key'])
len(unique_project_submitters)
# Out:
# 743

# %% [markdown]
# ### 딕셔너리의 특정 컬럼명 변경하기

# %%
for engagement_record in daily_engagement:
    engagement_record['account_key'] = engagement_record['acct']
    del(engagement_record['acct'])

# %%
dict_profile = {'name':'Jason Nam', 'age':'39', 'gen':'male'}

# %%
dict_profile['gender'] = dict_profile['gen']

# %%
dict_profile
# Out:
# {'age': '39', 'gen': 'male', 'gender': 'male', 'name': 'Jason Nam'}

# %%
del(dict_profile['gen'])

# %%
dict_profile
# Out:
# {'age': '39', 'gender': 'male', 'name': 'Jason Nam'}

# %%
def get_unique_students(data):
    unique_students = set()
    for data_point in data:
        unique_students.add(data_point['account_key'])
    return unique_students

# %%
daily_engagement[0]['account_key']
