# %% [markdown]
# Before we get started, a couple of reminders to keep in mind when using iPython notebooks:
#
# - Remember that you can see from the left side of a code cell when it was last run if there is a number within the brackets.
# - When you start a new notebook session, make sure you run all of the cells up to the point where you last left off. Even if the output is still visible from when you ran the cells in your previous session, the kernel starts in a fresh state so you'll need to reload the data, etc. on a new session.
# - The previous point is useful to keep in mind if your answers do not match what is expected in the lesson's quizzes. Try reloading the data and run all of the processing steps one by one in order to make sure that you are working with the same variables and data that are at each quiz stage.
#
#
# ## Load Data from CSVs

# %%
import unicodecsv

## Longer version of code (replaced with shorter, equivalent version below)

# enrollments = []
# f = open('enrollments.csv', 'rb')
# reader = unicodecsv.DictReader(f)
# for row in reader:
#     enrollments.append(row)
# f.close()

def read_csv(filename):
    with open(filename, 'rb') as f:
        reader = unicodecsv.DictReader(f)
        return list(reader)

# %%
#####################################
#                 1                 #
#####################################

## Read in the data from daily_engagement.csv and project_submissions.csv 
## and store the results in the below variables.
## Then look at the first row of each table.

enrollments = read_csv('./csv/enrollments.csv')
daily_engagement = read_csv('./csv/daily_engagement.csv')
project_submissions = read_csv('./csv/project_submissions.csv')

# %%
enrollments
# Out:
# [{'account_key': '448',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'True',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '448',
#   'cancel_date': '2014-11-10',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'True',
#   'join_date': '2014-11-05',
#   'status': 'canceled'},
#  {'account_key': '448',
#   'cancel_date': '2015-01-27',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'True',
#   'join_date': '2015-01-27',
#   'status': 'canceled'},
#  {'account_key': '448',
#   'cancel_date': '2014-11-10',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'True',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '448',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'True',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '448',
#   'cancel_date': '2015-01-27',
#   'days_to_cancel': '13',
#   'is_canceled': 'True',
#   'is_udacity': 'True',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '448',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '42',
#   'is_canceled': 'True',
#   'is_udacity': 'True',
#   'join_date': '2015-01-27',
#   'status': 'canceled'},
#  {'account_key': '448',
#   'cancel_date': '2015-01-27',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'True',
#   'join_date': '2015-01-27',
#   'status': 'canceled'},
#  {'account_key': '448',
#   'cancel_date': '2015-01-27',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'True',
#   'join_date': '2015-01-27',
#   'status': 'canceled'},
#  {'account_key': '700',
#   'cancel_date': '2014-11-16',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '429',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '429',
#   'cancel_date': '2015-06-17',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '60',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '60',
#   'cancel_date': '2015-04-01',
#   'days_to_cancel': '77',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '60',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-01',
#   'status': 'current'},
#  {'account_key': '1300',
#   'cancel_date': '2014-11-16',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '369',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '322',
#   'cancel_date': '2015-02-02',
#   'days_to_cancel': '84',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '322',
#   'cancel_date': '2015-02-12',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-12',
#   'status': 'canceled'},
#  {'account_key': '322',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '26',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-12',
#   'status': 'canceled'},
#  {'account_key': '322',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '336',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '553',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '584',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '584',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '55',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '584',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '1006',
#   'cancel_date': '2014-11-17',
#   'days_to_cancel': '7',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '458',
#   'cancel_date': '2015-04-01',
#   'days_to_cancel': '142',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '458',
#   'cancel_date': '2015-04-06',
#   'days_to_cancel': '2',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-04-04',
#   'status': 'canceled'},
#  {'account_key': '458',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-06',
#   'status': 'current'},
#  {'account_key': '1058',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '1058',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '55',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '1058',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '206',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '45',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '45',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '315',
#   'cancel_date': '2015-05-17',
#   'days_to_cancel': '188',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '604',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '204',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '408',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '408',
#   'cancel_date': '2015-04-01',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '408',
#   'cancel_date': '2015-04-17',
#   'days_to_cancel': '16',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-04-01',
#   'status': 'canceled'},
#  {'account_key': '51',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '51',
#   'cancel_date': '2015-06-17',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '323',
#   'cancel_date': '2015-04-17',
#   'days_to_cancel': '158',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '568',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '130',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '130',
#   'cancel_date': '2015-04-01',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '130',
#   'cancel_date': '2015-06-17',
#   'days_to_cancel': '77',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-04-01',
#   'status': 'canceled'},
#  {'account_key': '550',
#   'cancel_date': '2015-05-02',
#   'days_to_cancel': '173',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '550',
#   'cancel_date': '2015-07-04',
#   'days_to_cancel': '37',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-28',
#   'status': 'canceled'},
#  {'account_key': '44',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '44',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '1020',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '838',
#   'cancel_date': '2014-11-11',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '198',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '368',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '440',
#   'cancel_date': '2015-02-18',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '675',
#   'cancel_date': '2014-11-16',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '57',
#   'cancel_date': '2015-02-18',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '57',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-06',
#   'status': 'current'},
#  {'account_key': '1090',
#   'cancel_date': '2014-11-26',
#   'days_to_cancel': '15',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '541',
#   'cancel_date': '2015-06-19',
#   'days_to_cancel': '219',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '756',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '3',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '756',
#   'cancel_date': '2015-01-15',
#   'days_to_cancel': '61',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '1219',
#   'cancel_date': '2014-11-12',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '101',
#   'cancel_date': '2015-04-20',
#   'days_to_cancel': '159',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '1021',
#   'cancel_date': '2014-11-17',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '1108',
#   'cancel_date': '2014-11-16',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '800',
#   'cancel_date': '2014-11-14',
#   'days_to_cancel': '2',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '800',
#   'cancel_date': '2015-05-11',
#   'days_to_cancel': '68',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'canceled'},
#  {'account_key': '702',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '2',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-13',
#   'status': 'canceled'},
#  {'account_key': '702',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '60',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '702',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '55',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '702',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '871',
#   'cancel_date': '2014-11-13',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-13',
#   'status': 'canceled'},
#  {'account_key': '38',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'current'},
#  {'account_key': '215',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'current'},
#  {'account_key': '744',
#   'cancel_date': '2014-12-21',
#   'days_to_cancel': '37',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '217',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '217',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '115',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '217',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '1221',
#   'cancel_date': '2014-11-21',
#   'days_to_cancel': '7',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '1211',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '1211',
#   'cancel_date': '2015-01-15',
#   'days_to_cancel': '61',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '1211',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-06',
#   'status': 'current'},
#  {'account_key': '1051',
#   'cancel_date': '2014-11-16',
#   'days_to_cancel': '2',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '1286',
#   'cancel_date': '2014-11-21',
#   'days_to_cancel': '7',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '53',
#   'cancel_date': '2014-12-21',
#   'days_to_cancel': '37',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '53',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-11',
#   'status': 'current'},
#  {'account_key': '895',
#   'cancel_date': '2014-11-19',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '895',
#   'cancel_date': '2014-11-11',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '283',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'current'},
#  {'account_key': '283',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '2',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-13',
#   'status': 'canceled'},
#  {'account_key': '338',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '60',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '338',
#   'cancel_date': '2015-02-03',
#   'days_to_cancel': '20',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '338',
#   'cancel_date': '2015-02-22',
#   'days_to_cancel': '19',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-03',
#   'status': 'canceled'},
#  {'account_key': '338',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-11',
#   'status': 'current'},
#  {'account_key': '579',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'current'},
#  {'account_key': '903',
#   'cancel_date': '2014-11-21',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-16',
#   'status': 'canceled'},
#  {'account_key': '627',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-16',
#   'status': 'current'},
#  {'account_key': '253',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '59',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-16',
#   'status': 'canceled'},
#  {'account_key': '253',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'current'},
#  {'account_key': '861',
#   'cancel_date': '2014-11-19',
#   'days_to_cancel': '3',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-16',
#   'status': 'canceled'},
#  {'account_key': '178',
#   'cancel_date': '2015-05-09',
#   'days_to_cancel': '173',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-17',
#   'status': 'canceled'},
#  {'account_key': '822',
#   'cancel_date': '2015-01-15',
#   'days_to_cancel': '59',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-17',
#   'status': 'canceled'},
#  {'account_key': '822',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-07-18',
#   'status': 'current'},
#  {'account_key': '96',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-17',
#   'status': 'current'},
#  {'account_key': '123',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '123',
#   'cancel_date': '2015-04-17',
#   'days_to_cancel': '38',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '943',
#   'cancel_date': '2014-11-17',
#   'days_to_cancel': '7',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '620',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '1204',
#   'cancel_date': '2014-12-17',
#   'days_to_cancel': '37',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '195',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '890',
#   'cancel_date': '2014-11-11',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '354',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '837',
#   'cancel_date': '2014-11-11',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '114',
#   'cancel_date': '2014-11-11',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '114',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-08',
#   'status': 'current'},
#  {'account_key': '810',
#   'cancel_date': '2014-11-13',
#   'days_to_cancel': '3',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '394',
#   'cancel_date': '2015-04-17',
#   'days_to_cancel': '158',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '1253',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '1253',
#   'cancel_date': '2015-01-20',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '504',
#   'cancel_date': '2015-06-17',
#   'days_to_cancel': '219',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '537',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '72',
#   'cancel_date': '2015-05-17',
#   'days_to_cancel': '188',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '268',
#   'cancel_date': '2014-12-17',
#   'days_to_cancel': '37',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '268',
#   'cancel_date': '2015-08-10',
#   'days_to_cancel': '129',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-04-03',
#   'status': 'canceled'},
#  {'account_key': '339',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '339',
#   'cancel_date': '2015-06-17',
#   'days_to_cancel': '77',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-04-01',
#   'status': 'canceled'},
#  {'account_key': '339',
#   'cancel_date': '2015-04-01',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '1244',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '1244',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '1244',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '55',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '1244',
#   'cancel_date': '2015-04-27',
#   'days_to_cancel': '41',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-17',
#   'status': 'canceled'},
#  {'account_key': '1244',
#   'cancel_date': '2015-08-17',
#   'days_to_cancel': '92',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-17',
#   'status': 'canceled'},
#  {'account_key': '752',
#   'cancel_date': '2014-11-19',
#   'days_to_cancel': '9',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '194',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '520',
#   'cancel_date': '2015-03-17',
#   'days_to_cancel': '127',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '102',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '367',
#   'cancel_date': '2015-04-02',
#   'days_to_cancel': '142',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '258',
#   'cancel_date': '2015-07-17',
#   'days_to_cancel': '249',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '522',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '1047',
#   'cancel_date': '2014-11-11',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '329',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '329',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '29',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '329',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-08',
#   'status': 'current'},
#  {'account_key': '329',
#   'cancel_date': '2015-02-03',
#   'days_to_cancel': '20',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '329',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '35',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-03',
#   'status': 'canceled'},
#  {'account_key': '225',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '612',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '612',
#   'cancel_date': '2015-03-17',
#   'days_to_cancel': '7',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '150',
#   'cancel_date': '2015-05-17',
#   'days_to_cancel': '188',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '179',
#   'cancel_date': '2015-03-17',
#   'days_to_cancel': '127',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '595',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '587',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '587',
#   'cancel_date': '2015-04-17',
#   'days_to_cancel': '93',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '587',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-28',
#   'status': 'current'},
#  {'account_key': '439',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '439',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'current'},
#  {'account_key': '428',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '18',
#   'cancel_date': '2015-02-17',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '544',
#   'cancel_date': '2015-05-17',
#   'days_to_cancel': '188',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '10',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '913',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '65',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '913',
#   'cancel_date': '2015-02-17',
#   'days_to_cancel': '34',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '23',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '576',
#   'cancel_date': '2015-02-17',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '431',
#   'cancel_date': '2015-03-17',
#   'days_to_cancel': '127',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '223',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'current'},
#  {'account_key': '480',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '120',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '480',
#   'cancel_date': '2015-04-01',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '480',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-01',
#   'status': 'current'},
#  {'account_key': '525',
#   'cancel_date': '2015-07-17',
#   'days_to_cancel': '249',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-10',
#   'status': 'canceled'},
#  {'account_key': '1111',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '119',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '1111',
#   'cancel_date': '2015-04-01',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '1111',
#   'cancel_date': '2015-04-18',
#   'days_to_cancel': '17',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-04-01',
#   'status': 'canceled'},
#  {'account_key': '1107',
#   'cancel_date': '2014-11-19',
#   'days_to_cancel': '8',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '577',
#   'cancel_date': '2015-01-19',
#   'days_to_cancel': '68',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '577',
#   'cancel_date': '2015-07-12',
#   'days_to_cancel': '157',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-05',
#   'status': 'canceled'},
#  {'account_key': '92',
#   'cancel_date': '2015-07-19',
#   'days_to_cancel': '249',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '335',
#   'cancel_date': '2015-05-19',
#   'days_to_cancel': '188',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '275',
#   'cancel_date': '2014-11-16',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '275',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-16',
#   'status': 'current'},
#  {'account_key': '930',
#   'cancel_date': '2014-11-17',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-13',
#   'status': 'canceled'},
#  {'account_key': '245',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'current'},
#  {'account_key': '135',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'current'},
#  {'account_key': '37',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'current'},
#  {'account_key': '740',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '740',
#   'cancel_date': '2014-11-13',
#   'days_to_cancel': '2',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '186',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'current'},
#  {'account_key': '389',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'current'},
#  {'account_key': '389',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-14',
#   'status': 'canceled'},
#  {'account_key': '1218',
#   'cancel_date': '2014-11-15',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '693',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '60',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '693',
#   'cancel_date': '2015-01-23',
#   'days_to_cancel': '9',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '770',
#   'cancel_date': '2014-11-19',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '88',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '115',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '88',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-01',
#   'status': 'current'},
#  {'account_key': '88',
#   'cancel_date': '2015-04-01',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '845',
#   'cancel_date': '2014-11-23',
#   'days_to_cancel': '7',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-16',
#   'status': 'canceled'},
#  {'account_key': '983',
#   'cancel_date': '2015-01-14',
#   'days_to_cancel': '59',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-16',
#   'status': 'canceled'},
#  {'account_key': '983',
#   'cancel_date': '2015-01-23',
#   'days_to_cancel': '9',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-14',
#   'status': 'canceled'},
#  {'account_key': '1118',
#   'cancel_date': '2014-12-24',
#   'days_to_cancel': '37',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-17',
#   'status': 'canceled'},
#  {'account_key': '1118',
#   'cancel_date': '2014-11-17',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '499',
#   'cancel_date': '2014-11-17',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-17',
#   'status': 'canceled'},
#  {'account_key': '499',
#   'cancel_date': '2015-05-13',
#   'days_to_cancel': '96',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-06',
#   'status': 'canceled'},
#  {'account_key': '590',
#   'cancel_date': '2015-02-03',
#   'days_to_cancel': '62',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'canceled'},
#  {'account_key': '590',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-11',
#   'status': 'current'},
#  {'account_key': '590',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '35',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-03',
#   'status': 'canceled'},
#  {'account_key': '264',
#   'cancel_date': '2015-02-03',
#   'days_to_cancel': '62',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'canceled'},
#  {'account_key': '264',
#   'cancel_date': '2015-02-25',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-03',
#   'status': 'canceled'},
#  {'account_key': '300',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'current'},
#  {'account_key': '54',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'current'},
#  {'account_key': '1043',
#   'cancel_date': '2014-12-04',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'canceled'},
#  {'account_key': '1130',
#   'cancel_date': '2015-01-25',
#   'days_to_cancel': '53',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'canceled'},
#  {'account_key': '654',
#   'cancel_date': '2014-12-04',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-04',
#   'status': 'canceled'},
#  {'account_key': '654',
#   'cancel_date': '2014-12-04',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-04',
#   'status': 'canceled'},
#  {'account_key': '654',
#   'cancel_date': '2014-12-03',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'canceled'},
#  {'account_key': '736',
#   'cancel_date': '2015-03-11',
#   'days_to_cancel': '97',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-04',
#   'status': 'canceled'},
#  {'account_key': '964',
#   'cancel_date': '2014-12-04',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-04',
#   'status': 'canceled'},
#  {'account_key': '976',
#   'cancel_date': '2015-01-11',
#   'days_to_cancel': '38',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-04',
#   'status': 'canceled'},
#  {'account_key': '1203',
#   'cancel_date': '2014-12-09',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-04',
#   'status': 'canceled'},
#  {'account_key': '278',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-04',
#   'status': 'current'},
#  {'account_key': '377',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-05',
#   'status': 'current'},
#  {'account_key': '342',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-05',
#   'status': 'current'},
#  {'account_key': '358',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-05',
#   'status': 'current'},
#  {'account_key': '316',
#   'cancel_date': '2015-06-13',
#   'days_to_cancel': '189',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-06',
#   'status': 'canceled'},
#  {'account_key': '347',
#   'cancel_date': '2015-03-14',
#   'days_to_cancel': '97',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-07',
#   'status': 'canceled'},
#  {'account_key': '347',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-05',
#   'status': 'current'},
#  {'account_key': '295',
#   'cancel_date': '2014-12-07',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-07',
#   'status': 'canceled'},
#  {'account_key': '295',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-03',
#   'status': 'current'},
#  {'account_key': '343',
#   'cancel_date': '2015-03-14',
#   'days_to_cancel': '97',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-07',
#   'status': 'canceled'},
#  {'account_key': '1127',
#   'cancel_date': '2014-12-08',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-07',
#   'status': 'canceled'},
#  {'account_key': '1076',
#   'cancel_date': '2014-12-12',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-08',
#   'status': 'canceled'},
#  {'account_key': '502',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-08',
#   'status': 'current'},
#  {'account_key': '502',
#   'cancel_date': '2014-11-21',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-15',
#   'status': 'canceled'},
#  {'account_key': '1223',
#   'cancel_date': '2014-12-13',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-08',
#   'status': 'canceled'},
#  {'account_key': '221',
#   'cancel_date': '2015-02-10',
#   'days_to_cancel': '69',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'canceled'},
#  {'account_key': '631',
#   'cancel_date': '2014-12-08',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-03',
#   'status': 'canceled'},
#  {'account_key': '631',
#   'cancel_date': '2015-07-15',
#   'days_to_cancel': '68',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-08',
#   'status': 'canceled'},
#  {'account_key': '495',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-04',
#   'status': 'current'},
#  {'account_key': '495',
#   'cancel_date': '2014-11-17',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-12',
#   'status': 'canceled'},
#  {'account_key': '1009',
#   'cancel_date': '2015-02-12',
#   'days_to_cancel': '69',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-05',
#   'status': 'canceled'},
#  {'account_key': '364',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-05',
#   'status': 'current'},
#  {'account_key': '1252',
#   'cancel_date': '2014-12-11',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-05',
#   'status': 'canceled'},
#  {'account_key': '909',
#   'cancel_date': '2014-12-28',
#   'days_to_cancel': '23',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-05',
#   'status': 'canceled'},
#  {'account_key': '1156',
#   'cancel_date': '2014-12-08',
#   'days_to_cancel': '2',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-06',
#   'status': 'canceled'},
#  {'account_key': '524',
#   'cancel_date': '2015-02-03',
#   'days_to_cancel': '59',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-06',
#   'status': 'canceled'},
#  {'account_key': '524',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'current'},
#  {'account_key': '560',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-06',
#   'status': 'current'},
#  {'account_key': '570',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-07',
#   'status': 'current'},
#  {'account_key': '581',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-07',
#   'status': 'current'},
#  {'account_key': '759',
#   'cancel_date': '2015-02-03',
#   'days_to_cancel': '57',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-08',
#   'status': 'canceled'},
#  {'account_key': '759',
#   'cancel_date': '2015-04-15',
#   'days_to_cancel': '7',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-04-08',
#   'status': 'canceled'},
#  {'account_key': '759',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '64',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-03',
#   'status': 'canceled'},
#  {'account_key': '896',
#   'cancel_date': '2015-02-03',
#   'days_to_cancel': '57',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-08',
#   'status': 'canceled'},
#  {'account_key': '896',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '29',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '896',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '35',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-03',
#   'status': 'canceled'},
#  {'account_key': '896',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-08',
#   'status': 'current'},
#  {'account_key': '346',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2014-12-08',
#   'status': 'current'},
#  {'account_key': '346',
#   'cancel_date': '2014-12-05',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-05',
#   'status': 'canceled'},
#  {'account_key': '411',
#   'cancel_date': '2015-02-03',
#   'days_to_cancel': '57',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-08',
#   'status': 'canceled'},
#  {'account_key': '411',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '29',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-10',
#   'status': 'canceled'},
#  {'account_key': '411',
#   'cancel_date': '2015-03-10',
#   'days_to_cancel': '35',
# ...
#  {'account_key': '934',
#   'cancel_date': '2015-02-18',
#   'days_to_cancel': '38',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-01-11',
#   'status': 'canceled'},
#  {'account_key': '746',
#   'cancel_date': '2015-03-12',
#   'days_to_cancel': '35',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-05',
#   'status': 'canceled'},
#  {'account_key': '279',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '62',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-05',
#   'status': 'canceled'},
#  {'account_key': '279',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-08',
#   'status': 'current'},
#  {'account_key': '136',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '62',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-05',
#   'status': 'canceled'},
#  {'account_key': '136',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-08',
#   'status': 'current'},
#  {'account_key': '1092',
#   'cancel_date': '2015-02-09',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-05',
#   'status': 'canceled'},
#  {'account_key': '799',
#   'cancel_date': '2015-02-06',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-06',
#   'status': 'canceled'},
#  {'account_key': '1042',
#   'cancel_date': '2015-02-28',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-06',
#   'status': 'canceled'},
#  {'account_key': '1042',
#   'cancel_date': '2015-06-19',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-28',
#   'status': 'canceled'},
#  {'account_key': '789',
#   'cancel_date': '2015-02-06',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-06',
#   'status': 'canceled'},
#  {'account_key': '413',
#   'cancel_date': '2015-05-13',
#   'days_to_cancel': '96',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-06',
#   'status': 'canceled'},
#  {'account_key': '738',
#   'cancel_date': '2015-02-13',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-07',
#   'status': 'canceled'},
#  {'account_key': '306',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '59',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-08',
#   'status': 'canceled'},
#  {'account_key': '306',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-08',
#   'status': 'current'},
#  {'account_key': '436',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-02-08',
#   'status': 'current'},
#  {'account_key': '35',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-02-08',
#   'status': 'current'},
#  {'account_key': '463',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-02-09',
#   'status': 'current'},
#  {'account_key': '1105',
#   'cancel_date': '2015-02-13',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-09',
#   'status': 'canceled'},
#  {'account_key': '284',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '58',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-09',
#   'status': 'canceled'},
#  {'account_key': '284',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-08',
#   'status': 'current'},
#  {'account_key': '521',
#   'cancel_date': '2015-04-08',
#   'days_to_cancel': '58',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-09',
#   'status': 'canceled'},
#  {'account_key': '521',
#   'cancel_date': '2015-07-16',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-04-08',
#   'status': 'canceled'},
#  {'account_key': '1229',
#   'cancel_date': '2015-02-12',
#   'days_to_cancel': '3',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-09',
#   'status': 'canceled'},
#  {'account_key': '1049',
#   'cancel_date': '2015-03-04',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-10',
#   'status': 'canceled'},
#  {'account_key': '1198',
#   'cancel_date': '2015-02-15',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-02-11',
#   'status': 'canceled'},
#  {'account_key': '1198',
#   'cancel_date': '2015-04-11',
#   'days_to_cancel': '38',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'canceled'},
#  {'account_key': '720',
#   'cancel_date': '2015-04-11',
#   'days_to_cancel': '38',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'canceled'},
#  {'account_key': '239',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'current'},
#  {'account_key': '819',
#   'cancel_date': '2015-03-04',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'canceled'},
#  {'account_key': '819',
#   'cancel_date': '2015-03-04',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'canceled'},
#  {'account_key': '958',
#   'cancel_date': '2015-06-07',
#   'days_to_cancel': '95',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'canceled'},
#  {'account_key': '718',
#   'cancel_date': '2015-06-19',
#   'days_to_cancel': '42',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-08',
#   'status': 'canceled'},
#  {'account_key': '475',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-09',
#   'status': 'current'},
#  {'account_key': '276',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-10',
#   'status': 'current'},
#  {'account_key': '608',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-10',
#   'status': 'current'},
#  {'account_key': '293',
#   'cancel_date': '2015-08-17',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-10',
#   'status': 'canceled'},
#  {'account_key': '341',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-10',
#   'status': 'current'},
#  {'account_key': '501',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-11',
#   'status': 'current'},
#  {'account_key': '858',
#   'cancel_date': '2015-07-19',
#   'days_to_cancel': '68',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-12',
#   'status': 'canceled'},
#  {'account_key': '713',
#   'cancel_date': '2015-07-04',
#   'days_to_cancel': '53',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-12',
#   'status': 'canceled'},
#  {'account_key': '1040',
#   'cancel_date': '2015-06-19',
#   'days_to_cancel': '38',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-12',
#   'status': 'canceled'},
#  {'account_key': '1040',
#   'cancel_date': '2014-11-17',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '1305',
#   'cancel_date': '2015-06-19',
#   'days_to_cancel': '38',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-12',
#   'status': 'canceled'},
#  {'account_key': '1091',
#   'cancel_date': '2015-05-18',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-12',
#   'status': 'canceled'},
#  {'account_key': '1192',
#   'cancel_date': '2015-05-17',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-12',
#   'status': 'canceled'},
#  {'account_key': '25',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-12',
#   'status': 'current'},
#  {'account_key': '25',
#   'cancel_date': '2015-02-18',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-11-11',
#   'status': 'canceled'},
#  {'account_key': '674',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-12',
#   'status': 'current'},
#  {'account_key': '734',
#   'cancel_date': '2015-05-17',
#   'days_to_cancel': '4',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-13',
#   'status': 'canceled'},
#  {'account_key': '988',
#   'cancel_date': '2015-07-20',
#   'days_to_cancel': '68',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-13',
#   'status': 'canceled'},
#  {'account_key': '771',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-13',
#   'status': 'current'},
#  {'account_key': '771',
#   'cancel_date': '2014-12-15',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2014-12-09',
#   'status': 'canceled'},
#  {'account_key': '1016',
#   'cancel_date': '2015-05-19',
#   'days_to_cancel': '6',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-13',
#   'status': 'canceled'},
#  {'account_key': '877',
#   'cancel_date': '2015-06-04',
#   'days_to_cancel': '22',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-13',
#   'status': 'canceled'},
#  {'account_key': '63',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-28',
#   'status': 'current'},
#  {'account_key': '481',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-28',
#   'status': 'current'},
#  {'account_key': '902',
#   'cancel_date': '2015-05-29',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-29',
#   'status': 'canceled'},
#  {'account_key': '996',
#   'cancel_date': '2015-05-29',
#   'days_to_cancel': '0',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-29',
#   'status': 'canceled'},
#  {'account_key': '42',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-30',
#   'status': 'current'},
#  {'account_key': '42',
#   'cancel_date': '2015-05-11',
#   'days_to_cancel': '68',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-03-04',
#   'status': 'canceled'},
#  {'account_key': '939',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-24',
#   'status': 'current'},
#  {'account_key': '11',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-24',
#   'status': 'current'},
#  {'account_key': '262',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-24',
#   'status': 'current'},
#  {'account_key': '167',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-24',
#   'status': 'current'},
#  {'account_key': '302',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-24',
#   'status': 'current'},
#  {'account_key': '551',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-24',
#   'status': 'current'},
#  {'account_key': '609',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-04-24',
#   'status': 'current'},
#  {'account_key': '109',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-06',
#   'status': 'current'},
#  {'account_key': '211',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-06',
#   'status': 'current'},
#  {'account_key': '274',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-06',
#   'status': 'current'},
#  {'account_key': '704',
#   'cancel_date': '2015-07-13',
#   'days_to_cancel': '68',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-06',
#   'status': 'canceled'},
#  {'account_key': '407',
#   'cancel_date': '2015-08-13',
#   'days_to_cancel': '99',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-06',
#   'status': 'canceled'},
#  {'account_key': '360',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-06',
#   'status': 'current'},
#  {'account_key': '540',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-08',
#   'status': 'current'},
#  {'account_key': '1173',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-08',
#   'status': 'current'},
#  {'account_key': '886',
#   'cancel_date': '2015-05-13',
#   'days_to_cancel': '5',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-08',
#   'status': 'canceled'},
#  {'account_key': '112',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-08',
#   'status': 'current'},
#  {'account_key': '479',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-09',
#   'status': 'current'},
#  {'account_key': '1275',
#   'cancel_date': '2015-05-11',
#   'days_to_cancel': '2',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-09',
#   'status': 'canceled'},
#  {'account_key': '237',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-10',
#   'status': 'current'},
#  {'account_key': '487',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-10',
#   'status': 'current'},
#  {'account_key': '304',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-10',
#   'status': 'current'},
#  {'account_key': '330',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-10',
#   'status': 'current'},
#  {'account_key': '1250',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-11',
#   'status': 'current'},
#  {'account_key': '27',
#   'cancel_date': '',
#   'days_to_cancel': '',
#   'is_canceled': 'False',
#   'is_udacity': 'False',
#   'join_date': '2015-05-11',
#   'status': 'current'},
#  {'account_key': '1064',
#   'cancel_date': '2015-05-12',
#   'days_to_cancel': '1',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-11',
#   'status': 'canceled'},
#  {'account_key': '714',
#   'cancel_date': '2015-05-14',
#   'days_to_cancel': '3',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-05-11',
#   'status': 'canceled'},
#  {'account_key': '714',
#   'cancel_date': '2015-07-12',
#   'days_to_cancel': '3',
#   'is_canceled': 'True',
#   'is_udacity': 'False',
#   'join_date': '2015-07-09',
#   'status': 'canceled'},
#  ...]

# %%
project_submissions
# Out:
# [{'account_key': '256',
#   'assigned_rating': 'UNGRADED',
#   'completion_date': '2015-01-16',
#   'creation_date': '2015-01-14',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '256',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-13',
#   'creation_date': '2015-01-10',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '256',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-20',
#   'creation_date': '2015-01-20',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '434',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-13',
#   'creation_date': '2015-03-10',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '434',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-03-03',
#   'creation_date': '2015-02-17',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '381',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-06',
#   'creation_date': '2015-04-06',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '381',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-28',
#   'creation_date': '2015-07-26',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '381',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-02',
#   'creation_date': '2015-05-31',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '381',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-29',
#   'creation_date': '2015-07-29',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '381',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-29',
#   'creation_date': '2015-07-29',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '381',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-13',
#   'creation_date': '2015-04-07',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '381',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-06',
#   'creation_date': '2015-04-06',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '381',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-05',
#   'creation_date': '2015-04-05',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '378',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-23',
#   'creation_date': '2015-01-13',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '23',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-02',
#   'creation_date': '2015-03-19',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '23',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-11',
#   'creation_date': '2015-01-29',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '23',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-02-03',
#   'creation_date': '2015-01-29',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '23',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-21',
#   'creation_date': '2015-01-08',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '23',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-07',
#   'creation_date': '2014-12-24',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '23',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-02-25',
#   'creation_date': '2015-02-11',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '23',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-11',
#   'creation_date': '2015-02-26',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '23',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-19',
#   'creation_date': '2015-02-06',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-31',
#   'creation_date': '2015-07-23',
#   'lesson_key': '4110338963',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-21',
#   'creation_date': '2015-07-21',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-11',
#   'creation_date': '2015-07-10',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-18',
#   'creation_date': '2015-07-18',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-11',
#   'creation_date': '2015-06-11',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-10',
#   'creation_date': '2015-06-10',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-21',
#   'creation_date': '2015-07-20',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-15',
#   'creation_date': '2015-07-14',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-12',
#   'creation_date': '2015-06-12',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-04',
#   'creation_date': '2015-07-31',
#   'lesson_key': '4110338963',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-23',
#   'creation_date': '2015-06-22',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-12',
#   'creation_date': '2015-06-11',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-29',
#   'creation_date': '2015-06-29',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-26',
#   'creation_date': '2015-06-26',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '616',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-09',
#   'creation_date': '2015-06-05',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '223',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-15',
#   'creation_date': '2014-12-31',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '223',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-18',
#   'creation_date': '2015-03-10',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '152',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-21',
#   'creation_date': '2015-01-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '152',
#   'assigned_rating': 'DISTINCTION',
#   'completion_date': '2015-03-19',
#   'creation_date': '2015-03-09',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '152',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-09',
#   'creation_date': '2015-03-05',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-12',
#   'creation_date': '2015-08-12',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-12',
#   'creation_date': '2015-08-11',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-06',
#   'creation_date': '2015-08-06',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-29',
#   'creation_date': '2015-07-28',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-04',
#   'creation_date': '2015-05-03',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'UNGRADED',
#   'completion_date': '2015-03-11',
#   'creation_date': '2015-03-10',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-11',
#   'creation_date': '2015-08-10',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-26',
#   'creation_date': '2015-01-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1098',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-26',
#   'creation_date': '2015-03-11',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '273',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-28',
#   'creation_date': '2015-05-25',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '273',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-02-17',
#   'creation_date': '2015-02-03',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '273',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-26',
#   'creation_date': '2015-01-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '273',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-07',
#   'creation_date': '2015-03-24',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '273',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-20',
#   'creation_date': '2015-03-10',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '599',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-25',
#   'creation_date': '2015-08-25',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '599',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-03',
#   'creation_date': '2015-08-03',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '639',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2014-12-23',
#   'creation_date': '2014-12-14',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '639',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-26',
#   'creation_date': '2015-01-13',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '324',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-19',
#   'creation_date': '2015-08-19',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '324',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-12',
#   'creation_date': '2015-07-12',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '324',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-27',
#   'creation_date': '2015-07-26',
#   'lesson_key': '4582204201',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '324',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-19',
#   'creation_date': '2015-08-19',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-10',
#   'creation_date': '2015-08-10',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-09',
#   'creation_date': '2015-08-09',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-18',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-07',
#   'creation_date': '2015-01-03',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-09',
#   'creation_date': '2015-08-09',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-27',
#   'creation_date': '2015-03-22',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-11',
#   'creation_date': '2015-08-11',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-29',
#   'creation_date': '2015-07-28',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '439',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-06',
#   'creation_date': '2015-08-06',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '608',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-12',
#   'creation_date': '2015-06-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '608',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-12',
#   'creation_date': '2015-06-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '608',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-11',
#   'creation_date': '2015-06-11',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '30',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-03',
#   'creation_date': '2015-02-16',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '30',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-21',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '30',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-19',
#   'creation_date': '2015-02-16',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '30',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-17',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '168',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-10',
#   'creation_date': '2015-04-10',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '168',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-30',
#   'creation_date': '2015-06-29',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '168',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-04',
#   'creation_date': '2015-05-04',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '168',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-15',
#   'creation_date': '2015-04-15',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '224',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-27',
#   'creation_date': '2015-07-26',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '224',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-15',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '224',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-26',
#   'creation_date': '2015-08-25',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '224',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-25',
#   'creation_date': '2015-08-25',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '224',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-25',
#   'creation_date': '2015-01-11',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '224',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-07',
#   'creation_date': '2015-05-04',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '224',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-19',
#   'creation_date': '2015-03-10',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '224',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-11',
#   'creation_date': '2015-01-28',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1206',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-03',
#   'creation_date': '2015-08-02',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '575',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-24',
#   'creation_date': '2015-08-24',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '575',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-20',
#   'creation_date': '2015-07-19',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '575',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-20',
#   'creation_date': '2015-07-20',
#   'lesson_key': '4582204201',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '575',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-10',
#   'creation_date': '2015-08-10',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-17',
#   'creation_date': '2015-04-16',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-15',
#   'creation_date': '2015-04-15',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-20',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-16',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-06',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-13',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-26',
#   'creation_date': '2015-04-25',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-16',
#   'creation_date': '2015-04-16',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-15',
#   'creation_date': '2015-04-15',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-15',
#   'creation_date': '2015-04-14',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-01',
#   'creation_date': '2015-04-30',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-15',
#   'creation_date': '2015-04-15',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-13',
#   'creation_date': '2015-04-13',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-12',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-23',
#   'creation_date': '2015-04-23',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-12',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '641',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-08',
#   'creation_date': '2015-04-08',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '156',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-12',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '156',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-08',
#   'creation_date': '2015-05-05',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '156',
#   'assigned_rating': 'DISTINCTION',
#   'completion_date': '2015-01-26',
#   'creation_date': '2015-01-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '156',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-10',
#   'creation_date': '2015-06-09',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '156',
#   'assigned_rating': 'DISTINCTION',
#   'completion_date': '2015-03-18',
#   'creation_date': '2015-03-09',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '232',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-03',
#   'creation_date': '2015-08-02',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '232',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-21',
#   'creation_date': '2015-02-08',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '232',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-27',
#   'creation_date': '2015-07-27',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '232',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-05',
#   'creation_date': '2015-05-05',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-24',
#   'creation_date': '2015-07-24',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-24',
#   'creation_date': '2015-07-23',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-13',
#   'creation_date': '2015-06-13',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-07',
#   'creation_date': '2015-08-01',
#   'lesson_key': '4110338963',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-23',
#   'creation_date': '2015-07-22',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-14',
#   'creation_date': '2015-06-14',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-14',
#   'creation_date': '2015-06-14',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-11',
#   'creation_date': '2015-06-10',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-11',
#   'creation_date': '2015-08-11',
#   'lesson_key': '4110338963',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-03',
#   'creation_date': '2015-07-02',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-11',
#   'creation_date': '2015-06-11',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-13',
#   'creation_date': '2015-06-13',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '484',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-03',
#   'creation_date': '2015-07-03',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1224',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-29',
#   'creation_date': '2015-07-28',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-11',
#   'creation_date': '2015-07-10',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-30',
#   'creation_date': '2015-05-30',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '1',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-28',
#   'creation_date': '2015-05-28',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '611',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2014-12-31',
#   'creation_date': '2014-12-30',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '611',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-01',
#   'creation_date': '2014-12-12',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '611',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-18',
#   'creation_date': '2015-01-05',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '189',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-03',
#   'creation_date': '2015-07-01',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '189',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-29',
#   'creation_date': '2015-05-28',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '189',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-20',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-27',
#   'creation_date': '2015-08-27',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-06',
#   'creation_date': '2015-08-06',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-27',
#   'creation_date': '2015-07-26',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-25',
#   'creation_date': '2015-08-23',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-25',
#   'creation_date': '2015-06-25',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-22',
#   'creation_date': '2015-06-22',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-07',
#   'creation_date': '2015-08-07',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-24',
#   'creation_date': '2015-06-24',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '491',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-23',
#   'creation_date': '2015-06-23',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '535',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-02',
#   'creation_date': '2015-07-02',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '535',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-13',
#   'creation_date': '2015-04-01',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '57',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-08',
#   'creation_date': '2015-06-06',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '57',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2014-12-26',
#   'creation_date': '2014-12-19',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '57',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-05',
#   'creation_date': '2015-06-03',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '57',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-11',
#   'creation_date': '2015-02-10',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '57',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-22',
#   'creation_date': '2015-07-22',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '57',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-16',
#   'creation_date': '2015-01-10',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '57',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-26',
#   'creation_date': '2015-07-26',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '57',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-23',
#   'creation_date': '2015-07-22',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '61',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-25',
#   'creation_date': '2015-08-25',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '61',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-23',
#   'creation_date': '2015-08-23',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '61',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-28',
#   'creation_date': '2015-06-28',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '61',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-24',
#   'creation_date': '2015-08-24',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '61',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-22',
#   'creation_date': '2015-08-22',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '61',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-07',
#   'creation_date': '2015-06-07',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '375',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-21',
#   'creation_date': '2015-07-21',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '375',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-20',
#   'creation_date': '2015-07-20',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '375',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-22',
#   'creation_date': '2015-05-22',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '375',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-01',
#   'creation_date': '2015-05-01',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '375',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-01',
#   'creation_date': '2015-05-01',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '130',
#   'assigned_rating': 'UNGRADED',
#   'completion_date': '2015-02-21',
#   'creation_date': '2015-01-29',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '130',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-24',
#   'creation_date': '2015-02-24',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '130',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-21',
#   'creation_date': '2015-01-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '365',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-19',
#   'creation_date': '2015-08-19',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '365',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-03',
#   'creation_date': '2015-08-02',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '365',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-04',
#   'creation_date': '2015-08-04',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '365',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-19',
#   'creation_date': '2015-08-19',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '90',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-02-11',
#   'creation_date': '2015-01-31',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '90',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-14',
#   'creation_date': '2015-01-02',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '90',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-27',
#   'creation_date': '2015-08-25',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '90',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-02',
#   'creation_date': '2015-06-02',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '90',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-28',
#   'creation_date': '2015-01-14',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '90',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-27',
#   'creation_date': '2015-02-13',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '90',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-04',
#   'creation_date': '2015-06-04',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '694',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-26',
#   'creation_date': '2015-08-26',
#   'lesson_key': '4582204201',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '694',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-15',
#   'creation_date': '2015-07-14',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '84',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-28',
#   'creation_date': '2015-06-28',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '84',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-29',
#   'creation_date': '2015-05-29',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '84',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-01',
#   'creation_date': '2015-07-01',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '618',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-10',
#   'creation_date': '2015-01-30',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '712',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-20',
#   'creation_date': '2015-01-13',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '497',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-15',
#   'creation_date': '2015-07-15',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '497',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-05',
#   'creation_date': '2015-07-05',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '605',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-07',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '605',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-03-13',
#   'creation_date': '2015-03-11',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '605',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-07',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '313',
#   'assigned_rating': '',
#   'completion_date': '',
#   'creation_date': '2015-06-04',
#   'lesson_key': '3176718735',
#   'processing_state': 'CREATED'},
#  {'account_key': '313',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-04',
#   'creation_date': '2015-06-04',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '313',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-18',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '313',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-02',
#   'creation_date': '2015-02-25',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '313',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-13',
#   'creation_date': '2015-04-08',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '313',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-05',
#   'creation_date': '2015-04-04',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '537',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-19',
#   'creation_date': '2015-03-19',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '537',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-13',
#   'creation_date': '2014-12-30',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '537',
#   'assigned_rating': 'UNGRADED',
#   'completion_date': '2015-03-18',
#   'creation_date': '2015-03-04',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '581',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-24',
#   'creation_date': '2015-02-23',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '581',
#   'assigned_rating': 'DISTINCTION',
#   'completion_date': '2015-03-27',
#   'creation_date': '2015-03-24',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '581',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-29',
#   'creation_date': '2015-06-29',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '581',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-02-16',
#   'creation_date': '2015-02-02',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '581',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-04',
#   'creation_date': '2015-07-03',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '629',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-04',
#   'creation_date': '2015-08-03',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '629',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-05',
#   'creation_date': '2015-08-05',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '541',
#   'assigned_rating': 'DISTINCTION',
#   'completion_date': '2015-02-07',
#   'creation_date': '2015-01-25',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '541',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-14',
#   'creation_date': '2015-01-02',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '541',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-27',
#   'creation_date': '2015-02-12',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '541',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-13',
#   'creation_date': '2015-01-31',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '541',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-08',
#   'creation_date': '2015-03-27',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '541',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-07',
#   'creation_date': '2015-05-29',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '207',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-13',
#   'creation_date': '2015-04-04',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '207',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-29',
#   'creation_date': '2015-07-27',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '207',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-20',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '207',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-03-24',
#   'creation_date': '2015-03-15',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '207',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-23',
#   'creation_date': '2015-07-23',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '207',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-12',
#   'creation_date': '2015-06-12',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '207',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-16',
#   'creation_date': '2015-01-09',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '416',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-01',
#   'creation_date': '2015-06-01',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '416',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-31',
#   'creation_date': '2015-05-31',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '416',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-30',
#   'creation_date': '2015-05-30',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '612',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-03',
#   'creation_date': '2015-01-22',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '612',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-15',
#   'creation_date': '2015-01-02',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-14',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-08',
#   'creation_date': '2015-06-07',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-21',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-10',
#   'creation_date': '2015-06-09',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'DISTINCTION',
#   'completion_date': '2015-03-19',
#   'creation_date': '2015-03-06',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-06',
#   'creation_date': '2015-05-04',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-22',
#   'creation_date': '2015-01-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-19',
#   'creation_date': '2015-06-12',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-12',
#   'creation_date': '2015-06-10',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '258',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-01',
#   'creation_date': '2015-05-31',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '413',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-14',
#   'creation_date': '2015-03-30',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '413',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-02',
#   'creation_date': '2015-05-01',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '413',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-29',
#   'creation_date': '2015-04-23',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '652',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-05',
#   'creation_date': '2015-08-05',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '652',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-23',
#   'creation_date': '2015-08-23',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '652',
#   'assigned_rating': 'INCOMPLETE',
# ...
#   'completion_date': '2015-07-13',
#   'creation_date': '2015-07-13',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '185',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-19',
#   'creation_date': '2015-07-18',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '185',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-17',
#   'creation_date': '2015-07-17',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '185',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-27',
#   'creation_date': '2015-08-26',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '185',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-24',
#   'creation_date': '2015-08-24',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '396',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-20',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '396',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-29',
#   'creation_date': '2015-05-26',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '104',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-28',
#   'creation_date': '2015-07-27',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '104',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-14',
#   'creation_date': '2015-06-14',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '104',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-01',
#   'creation_date': '2015-05-31',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '104',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-28',
#   'creation_date': '2015-05-28',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '353',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-23',
#   'creation_date': '2015-04-23',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '166',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-02-09',
#   'creation_date': '2015-01-26',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '166',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-11',
#   'creation_date': '2015-08-10',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '166',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-24',
#   'creation_date': '2015-05-22',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '166',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-03-10',
#   'creation_date': '2015-02-24',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '166',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-27',
#   'creation_date': '2015-03-24',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '166',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-13',
#   'creation_date': '2015-08-12',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '166',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-03',
#   'creation_date': '2015-06-01',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '166',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-26',
#   'creation_date': '2015-03-14',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '72',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2014-12-03',
#   'creation_date': '2014-11-30',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '72',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-02-28',
#   'creation_date': '2015-02-21',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '72',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-03',
#   'creation_date': '2015-03-29',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '72',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2014-12-01',
#   'creation_date': '2014-11-22',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '162',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-23',
#   'creation_date': '2015-07-23',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '162',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-10',
#   'creation_date': '2015-06-10',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '162',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-31',
#   'creation_date': '2015-07-31',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '162',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-10',
#   'creation_date': '2015-06-09',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '181',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-23',
#   'creation_date': '2015-01-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '181',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-20',
#   'creation_date': '2015-03-10',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '525',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-23',
#   'creation_date': '2015-08-22',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '525',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-05',
#   'creation_date': '2015-07-05',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '525',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-07',
#   'creation_date': '2015-04-07',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '525',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-09',
#   'creation_date': '2014-12-29',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '525',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-16',
#   'creation_date': '2015-07-10',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '525',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-03-27',
#   'creation_date': '2015-03-20',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '525',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-07',
#   'creation_date': '2015-01-26',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '525',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-05',
#   'creation_date': '2015-04-01',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-18',
#   'creation_date': '2015-07-16',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-18',
#   'creation_date': '2015-07-18',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-20',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-03-17',
#   'creation_date': '2015-03-05',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-08',
#   'creation_date': '2015-08-08',
#   'lesson_key': '4110338963',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-07',
#   'creation_date': '2015-08-01',
#   'lesson_key': '4110338963',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-15',
#   'creation_date': '2015-07-14',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-10',
#   'creation_date': '2015-07-07',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-16',
#   'creation_date': '2015-07-15',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-30',
#   'creation_date': '2015-05-29',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-21',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-20',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-19',
#   'creation_date': '2015-07-18',
#   'lesson_key': '4582204201',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-06-04',
#   'creation_date': '2015-05-30',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '125',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-05-21',
#   'creation_date': '2015-05-19',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-24',
#   'creation_date': '2015-08-22',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-20',
#   'creation_date': '2015-07-13',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-29',
#   'creation_date': '2015-04-28',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-02-16',
#   'creation_date': '2015-02-01',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-28',
#   'creation_date': '2015-06-28',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-27',
#   'creation_date': '2015-06-27',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-17',
#   'creation_date': '2015-04-14',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-13',
#   'creation_date': '2015-04-12',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-24',
#   'creation_date': '2015-08-24',
#   'lesson_key': '3184238632',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-20',
#   'creation_date': '2015-04-19',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-15',
#   'creation_date': '2015-02-28',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-13',
#   'creation_date': '2015-07-13',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '570',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-01-31',
#   'creation_date': '2015-01-17',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '634',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-16',
#   'creation_date': '2015-04-16',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '634',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-04-13',
#   'creation_date': '2015-04-07',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '634',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-02-16',
#   'creation_date': '2015-02-01',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '634',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-15',
#   'creation_date': '2015-04-15',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '634',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-04-13',
#   'creation_date': '2015-03-29',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '634',
#   'assigned_rating': 'UNGRADED',
#   'completion_date': '2015-03-31',
#   'creation_date': '2015-03-29',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '634',
#   'assigned_rating': 'UNGRADED',
#   'completion_date': '2015-04-07',
#   'creation_date': '2015-03-29',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '21',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-07-28',
#   'creation_date': '2015-07-27',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '21',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-21',
#   'creation_date': '2015-07-21',
#   'lesson_key': '4582204201',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '21',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-05',
#   'creation_date': '2015-08-05',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '21',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-08-05',
#   'creation_date': '2015-08-05',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '21',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-07-18',
#   'creation_date': '2015-07-17',
#   'lesson_key': '4576183932',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '369',
#   'assigned_rating': 'UNGRADED',
#   'completion_date': '2015-05-26',
#   'creation_date': '2015-05-26',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '369',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-08-19',
#   'creation_date': '2015-08-18',
#   'lesson_key': '3174288624',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '369',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-16',
#   'creation_date': '2015-06-16',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '369',
#   'assigned_rating': 'INCOMPLETE',
#   'completion_date': '2015-06-03',
#   'creation_date': '2015-05-26',
#   'lesson_key': '3165188753',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '369',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-03-26',
#   'creation_date': '2015-03-09',
#   'lesson_key': '3168208620',
#   'processing_state': 'EVALUATED'},
#  {'account_key': '369',
#   'assigned_rating': 'PASSED',
#   'completion_date': '2015-01-23',
#   'creation_date': '2015-01-12',
#   'lesson_key': '3176718735',
#   'processing_state': 'EVALUATED'},
#  ...]

# %%
daily_engagement
# Out:
# [{'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '11.6793745',
#   'utc_date': '2015-01-09'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '37.2848873333',
#   'utc_date': '2015-01-10'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '53.6337463333',
#   'utc_date': '2015-01-11'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '33.4892696667',
#   'utc_date': '2015-01-12'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '64.7796776667',
#   'utc_date': '2015-01-13'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '151.617576833',
#   'utc_date': '2015-01-14'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '142.395963833',
#   'utc_date': '2015-01-15'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-01-16'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '9.8495625',
#   'utc_date': '2015-01-17'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '38.330548',
#   'utc_date': '2015-01-18'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '98.3275675',
#   'utc_date': '2015-01-19'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-01-20'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-01-21'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '218.309690167',
#   'utc_date': '2015-01-22'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '280.773319167',
#   'utc_date': '2015-01-23'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '32.2760201667',
#   'utc_date': '2015-01-24'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '65.467882',
#   'utc_date': '2015-01-25'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '74.806089',
#   'utc_date': '2015-01-26'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '199.5010495',
#   'utc_date': '2015-01-27'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '55.2349593333',
#   'utc_date': '2015-01-28'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '212.645668667',
#   'utc_date': '2015-01-29'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '96.0037191667',
#   'utc_date': '2015-01-30'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '94.333214',
#   'utc_date': '2015-01-31'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '40.564986',
#   'utc_date': '2015-02-01'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '75.525712',
#   'utc_date': '2015-02-02'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '147.728229',
#   'utc_date': '2015-02-03'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '38.5299701667',
#   'utc_date': '2015-02-04'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '84.9565343334',
#   'utc_date': '2015-02-05'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '101.378330333',
#   'utc_date': '2015-02-06'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '104.065235',
#   'utc_date': '2015-02-07'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-02-08'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '102.063156833',
#   'utc_date': '2015-02-09'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '104.679762333',
#   'utc_date': '2015-02-10'},
#  {'acct': '0',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '401.115233',
#   'utc_date': '2015-02-11'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '75.988601',
#   'utc_date': '2015-02-12'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '29.5425376667',
#   'utc_date': '2015-02-13'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '111.8835475',
#   'utc_date': '2015-02-14'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-02-15'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-02-16'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-02-17'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-02-18'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-02-19'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '32.6505448333',
#   'utc_date': '2015-02-20'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '62.9092253333',
#   'utc_date': '2015-02-21'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '77.8910681667',
#   'utc_date': '2015-02-22'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '149.886224833',
#   'utc_date': '2015-02-23'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-02-24'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '148.062158833',
#   'utc_date': '2015-02-25'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '42.3405491667',
#   'utc_date': '2015-02-26'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '32.479962',
#   'utc_date': '2015-02-27'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-02-28'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '76.5451126667',
#   'utc_date': '2015-03-01'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '52.3286868334',
#   'utc_date': '2015-03-02'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '72.9312528334',
#   'utc_date': '2015-03-03'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '75.3168575',
#   'utc_date': '2015-03-04'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '58.7287473333',
#   'utc_date': '2015-03-05'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '61.3593731667',
#   'utc_date': '2015-03-06'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-07'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-08'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '13.0344913333',
#   'utc_date': '2015-03-09'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '238.282677666',
#   'utc_date': '2015-03-10'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '90.317473',
#   'utc_date': '2015-03-11'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '20.3650096667',
#   'utc_date': '2015-03-12'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-13'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-14'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-15'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '164.301307834',
#   'utc_date': '2015-03-16'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '13.6127401667',
#   'utc_date': '2015-03-17'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '28.9673653334',
#   'utc_date': '2015-03-18'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-19'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-20'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-21'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-22'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '35.6879838333',
#   'utc_date': '2015-03-23'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '142.7344815',
#   'utc_date': '2015-03-24'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '175.6848335',
#   'utc_date': '2015-03-25'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '50.231326',
#   'utc_date': '2015-03-26'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-27'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-28'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-29'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-03-30'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '173.54588',
#   'utc_date': '2015-03-31'},
#  {'acct': '0',
#   'lessons_completed': '3.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '214.837217833',
#   'utc_date': '2015-04-01'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-02'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '59.0732133333',
#   'utc_date': '2015-04-03'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '35.71483',
#   'utc_date': '2015-04-04'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '103.655366',
#   'utc_date': '2015-04-05'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '171.518927',
#   'utc_date': '2015-04-06'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '14.3998386667',
#   'utc_date': '2015-04-07'},
#  {'acct': '0',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '115.690604167',
#   'utc_date': '2015-04-08'},
#  {'acct': '0',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '235.687231833',
#   'utc_date': '2015-04-09'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-10'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '41.9540113333',
#   'utc_date': '2015-04-11'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '17.4156996667',
#   'utc_date': '2015-04-12'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '10.4754313333',
#   'utc_date': '2015-04-13'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '37.0426483333',
#   'utc_date': '2015-04-14'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-15'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-16'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-17'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-18'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-19'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '25.2435245',
#   'utc_date': '2015-04-20'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '7.10464066667',
#   'utc_date': '2015-04-21'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-22'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '1.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-23'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-24'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-25'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-26'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-27'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '3.13019766667',
#   'utc_date': '2015-04-28'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-29'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-30'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-01'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-02'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-03'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-04'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-05'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-06'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-07'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '3.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '121.301107833',
#   'utc_date': '2015-05-08'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '78.9664818333',
#   'utc_date': '2015-05-09'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '39.1185718333',
#   'utc_date': '2015-05-10'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '130.237900333',
#   'utc_date': '2015-05-11'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '8.6603245',
#   'utc_date': '2015-05-12'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-13'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-14'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-15'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-16'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-17'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-18'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-19'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-20'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-21'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-22'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-23'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-24'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-25'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-26'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-27'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-28'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-29'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-30'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-31'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-01'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-02'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-03'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-04'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-05'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-06'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-07'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-08'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-09'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-10'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-11'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '12.2313653333',
#   'utc_date': '2015-06-12'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-13'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-14'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-15'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-16'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-17'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '75.9321218333',
#   'utc_date': '2015-06-18'},
#  {'acct': '0',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '72.5781645',
#   'utc_date': '2015-06-19'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-20'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-21'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-22'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-23'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '94.7982856667',
#   'utc_date': '2015-06-24'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-25'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '50.7091576667',
#   'utc_date': '2015-06-26'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-27'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '104.3308655',
#   'utc_date': '2015-06-28'},
#  {'acct': '0',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '211.402388167',
#   'utc_date': '2015-06-29'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '13.5055071667',
#   'utc_date': '2015-06-30'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-01'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-02'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-03'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-04'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-05'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-06'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-07'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-08'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-09'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-10'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-11'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-12'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-13'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-14'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-15'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-16'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-17'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-18'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-19'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-20'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-21'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-22'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-23'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-24'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-25'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '1.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-27'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-28'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-29'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-30'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-31'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-01'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-02'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-03'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-04'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-05'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-06'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-07'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-08'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-09'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-10'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-11'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-12'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-13'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '4.72941616667',
#   'utc_date': '2015-08-14'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-15'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-16'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-17'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-18'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-19'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-20'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-21'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-22'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-23'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-24'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-25'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '14.9694161667',
#   'utc_date': '2015-08-26'},
#  {'acct': '0',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-27'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '9.640248',
#   'utc_date': '2015-05-06'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-07'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-08'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-09'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-10'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-11'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '8.93613666667',
#   'utc_date': '2015-05-12'},
#  {'acct': '1',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '202.4374995',
#   'utc_date': '2015-05-13'},
#  {'acct': '1',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '300.820181667',
#   'utc_date': '2015-05-14'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '144.223258333',
#   'utc_date': '2015-05-15'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-16'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-17'},
#  {'acct': '1',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '250.7725985',
#   'utc_date': '2015-05-18'},
#  {'acct': '1',
#   'lessons_completed': '3.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '343.247496167',
#   'utc_date': '2015-05-19'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-20'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '63.902367',
#   'utc_date': '2015-05-21'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '189.458624167',
#   'utc_date': '2015-05-22'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-23'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-24'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-05-25'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '3.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '151.374713167',
#   'utc_date': '2015-05-26'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '125.0190875',
#   'utc_date': '2015-05-27'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '187.35692',
#   'utc_date': '2015-05-28'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '88.849618',
#   'utc_date': '2015-05-29'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '18.118867',
#   'utc_date': '2015-05-30'},
#  {'acct': '1',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '26.535007',
#   'utc_date': '2015-05-31'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-01'},
#  {'acct': '1',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '110.091891333',
#   'utc_date': '2015-06-02'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-03'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-04'},
#  {'acct': '1',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '195.111528',
#   'utc_date': '2015-06-05'},
#  {'acct': '1',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '62.8241491667',
#   'utc_date': '2015-06-06'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-07'},
#  {'acct': '1',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '130.313695834',
#   'utc_date': '2015-06-08'},
#  {'acct': '1',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '211.139601333',
#   'utc_date': '2015-06-09'},
#  {'acct': '1',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '71.3947381667',
#   'utc_date': '2015-06-10'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '159.567278667',
#   'utc_date': '2015-06-11'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '9.3085855',
#   'utc_date': '2015-06-12'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-13'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-14'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-15'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-16'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-17'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-18'},
#  {'acct': '1',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-19'},
# ...
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-06'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-07'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-08'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-09'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-10'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-11'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-12'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-13'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-14'},
#  {'acct': '5',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-04-15'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '5.63057216667',
#   'utc_date': '2015-06-05'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '76.5443475',
#   'utc_date': '2015-06-06'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '134.276672167',
#   'utc_date': '2015-06-07'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '203.849392833',
#   'utc_date': '2015-06-08'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '196.479387',
#   'utc_date': '2015-06-09'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '163.6741795',
#   'utc_date': '2015-06-10'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-11'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '28.2927066667',
#   'utc_date': '2015-06-12'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-13'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '172.595749667',
#   'utc_date': '2015-06-14'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '157.439929',
#   'utc_date': '2015-06-15'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '3.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '118.380186833',
#   'utc_date': '2015-06-16'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-17'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '52.6609141667',
#   'utc_date': '2015-06-18'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-19'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-20'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-21'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-22'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '9.60006966667',
#   'utc_date': '2015-06-23'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '147.642282',
#   'utc_date': '2015-06-24'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-06-25'},
#  {'acct': '6',
#   'lessons_completed': '3.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '114.949999667',
#   'utc_date': '2015-06-26'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '196.947144833',
#   'utc_date': '2015-06-27'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '15.7023031667',
#   'utc_date': '2015-06-28'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '10.1590001667',
#   'utc_date': '2015-06-29'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '132.987784333',
#   'utc_date': '2015-06-30'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '105.176804167',
#   'utc_date': '2015-07-01'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '85.0438933334',
#   'utc_date': '2015-07-02'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-03'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-04'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-05'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-06'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '17.3480545',
#   'utc_date': '2015-07-07'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-08'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '133.041100333',
#   'utc_date': '2015-07-09'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-10'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-11'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-12'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-13'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '124.933725667',
#   'utc_date': '2015-07-14'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-15'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '139.111612667',
#   'utc_date': '2015-07-16'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '79.3535321667',
#   'utc_date': '2015-07-17'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '133.886249667',
#   'utc_date': '2015-07-18'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-19'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '91.9906563333',
#   'utc_date': '2015-07-20'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '138.885445833',
#   'utc_date': '2015-07-21'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '24.1459173333',
#   'utc_date': '2015-07-22'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '119.308748333',
#   'utc_date': '2015-07-23'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-24'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-25'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-27'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '24.0452185',
#   'utc_date': '2015-07-28'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-29'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-07-30'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '11.6307113333',
#   'utc_date': '2015-07-31'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-01'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-02'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-03'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '197.103019667',
#   'utc_date': '2015-08-04'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '98.0322758333',
#   'utc_date': '2015-08-05'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '78.1249156667',
#   'utc_date': '2015-08-06'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-07'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '99.0882603333',
#   'utc_date': '2015-08-08'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '71.5235561667',
#   'utc_date': '2015-08-09'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '52.0986663333',
#   'utc_date': '2015-08-10'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-11'},
#  {'acct': '6',
#   'lessons_completed': '1.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '75.741122',
#   'utc_date': '2015-08-12'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '41.2572078333',
#   'utc_date': '2015-08-13'},
#  {'acct': '6',
#   'lessons_completed': '2.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '102.0324245',
#   'utc_date': '2015-08-14'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-15'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-16'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-17'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '2.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '31.5542495',
#   'utc_date': '2015-08-18'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-19'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-20'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '4.79160833333',
#   'utc_date': '2015-08-21'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-22'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '1.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '30.99737',
#   'utc_date': '2015-08-23'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-24'},
#  {'acct': '6',
#   'lessons_completed': '0.0',
#   'num_courses_visited': '0.0',
#   'projects_completed': '0.0',
#   'total_minutes_visited': '0.0',
#   'utc_date': '2015-08-25'},
#  ...]

# %% [markdown]
# ## Fixing Data Types

# %%
from datetime import datetime as dt

# Takes a date as a string, and returns a Python datetime object. 
# If there is no date given, returns None
def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
# Takes a string which is either an empty string or represents an integer,
# and returns an int or None.
def parse_maybe_int(i):
    if i == '':
        return None
    else:
        return int(i)

# Clean up the data types in the enrollments table
for enrollment in enrollments:
    enrollment['cancel_date'] = parse_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['join_date'] = parse_date(enrollment['join_date'])
    
enrollments[0]
# Out:
# {'account_key': '448',
#  'cancel_date': datetime.datetime(2015, 1, 14, 0, 0),
#  'days_to_cancel': 65,
#  'is_canceled': True,
#  'is_udacity': True,
#  'join_date': datetime.datetime(2014, 11, 10, 0, 0),
#  'status': 'canceled'}

# %%
# Clean up the data types in the engagement table
for engagement_record in daily_engagement:
    engagement_record['lessons_completed'] = int(float(engagement_record['lessons_completed']))
    engagement_record['num_courses_visited'] = int(float(engagement_record['num_courses_visited']))
    engagement_record['projects_completed'] = int(float(engagement_record['projects_completed']))
    engagement_record['total_minutes_visited'] = float(engagement_record['total_minutes_visited'])
    engagement_record['utc_date'] = parse_date(engagement_record['utc_date'])
    
daily_engagement[0]
# Out:
# {'acct': '0',
#  'lessons_completed': 0,
#  'num_courses_visited': 1,
#  'projects_completed': 0,
#  'total_minutes_visited': 11.6793745,
#  'utc_date': datetime.datetime(2015, 1, 9, 0, 0)}

# %%
# Clean up the data types in the submissions table
for submission in project_submissions:
    submission['completion_date'] = parse_date(submission['completion_date'])
    submission['creation_date'] = parse_date(submission['creation_date'])

project_submissions[0]
# Out:
# {'account_key': '256',
#  'assigned_rating': 'UNGRADED',
#  'completion_date': datetime.datetime(2015, 1, 16, 0, 0),
#  'creation_date': datetime.datetime(2015, 1, 14, 0, 0),
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %% [markdown]
# Note when running the above cells that we are actively changing the contents of our data variables. If you try to run these cells multiple times in the same session, an error will occur.
#
# ## Investigating the Data

# %%
#####################################
#                 2                 #
#####################################

## Find the total number of rows and the number of unique students (account keys)
## in each table.

# enrollments
num_row_enrollments = len(enrollments)
num_row_engagement = len(daily_engagement)
num_row_submission = len(project_submissions)

print('num_of_row_enrollments : %d' % num_row_enrollments)
print('num_of_row_engagement : %d' % num_row_engagement)
print('num_of_row_submission : %d' % num_row_submission)
# Out:
# num_of_row_enrollments : 1640
# num_of_row_engagement : 136240
# num_of_row_submission : 3642

# %% [markdown]
# ## Problems in the Data

# %%
#####################################
#                 3                 #
#####################################

## Rename the "acct" column in the daily_engagement table to "account_key".
for engagement in daily_engagement:
    engagement['account_key'] = engagement['acct']
    del(engagement['acct'])
    
def get_unique_students(data):
    unique_students = set()
    
    for data_point in data:
        unique_students.add(data_point['account_key'])
    
    return unique_students

# unique_enrolled_students
unique_enrolled_students = get_unique_students(enrollments)
print('unique_enrolled_students : %d' % len(unique_enrolled_students))

# unique_engagement
unique_engagement = get_unique_students(daily_engagement)
print('unique_engagement : %d' % len(unique_engagement))

# unique_project_submission
unique_project_submission = get_unique_students(project_submissions)
print('unique_project_submission : %d' % len(unique_project_submission))
# Out:
# unique_enrolled_students : 1302
# unique_engagement : 1237
# unique_project_submission : 743

# %%
daily_engagement[0]['account_key']
# Out:
# '0'

# %% [markdown]
# ## Missing Engagement Records

# %%
#####################################
#                 4                 #
#####################################

## Find any one student enrollments where the student is missing from the daily engagement table.
## Output that enrollment.
for enrollment in enrollments:
    student = enrollment['account_key']
    if student not in unique_engagement:
        print(enrollment)
        break
# Out:
# {'join_date': datetime.datetime(2014, 11, 12, 0, 0), 'cancel_date': datetime.datetime(2014, 11, 12, 0, 0), 'account_key': '1219', 'days_to_cancel': 0, 'is_canceled': True, 'is_udacity': False, 'status': 'canceled'}

# %% [markdown]
# ## Checking for More Problem Records

# %%
#####################################
#                 5                 #
#####################################

## Find the number of surprising data points (enrollments missing from
## the engagement table) that remain, if any.
num_problem_students = 0

for enrollment in enrollments:
    student = enrollment['account_key']
    if student not in unique_engagement and enrollment['join_date'] != enrollment['cancel_date']:
        num_problem_students += 1
        print(enrollment)
        
num_problem_students
# Out:
# {'join_date': datetime.datetime(2015, 1, 10, 0, 0), 'cancel_date': datetime.datetime(2015, 3, 10, 0, 0), 'account_key': '1304', 'days_to_cancel': 59, 'is_canceled': True, 'is_udacity': True, 'status': 'canceled'}
# {'join_date': datetime.datetime(2015, 3, 10, 0, 0), 'cancel_date': datetime.datetime(2015, 6, 17, 0, 0), 'account_key': '1304', 'days_to_cancel': 99, 'is_canceled': True, 'is_udacity': True, 'status': 'canceled'}
# {'join_date': datetime.datetime(2015, 2, 25, 0, 0), 'cancel_date': None, 'account_key': '1101', 'days_to_cancel': None, 'is_canceled': False, 'is_udacity': True, 'status': 'current'}
# 3

# %% [markdown]
# ## Tracking Down the Remaining Problems

# %%
# Create a set of the account keys for all Udacity test accounts
udacity_test_accounts = set()
for enrollment in enrollments:
    if enrollment['is_udacity']:
        udacity_test_accounts.add(enrollment['account_key'])
len(udacity_test_accounts)
# Out:
# 6

# %%
# Given some data with an account_key field, removes any records corresponding to Udacity test accounts
def remove_udacity_accounts(data):
    non_udacity_data = []
    for data_point in data:
        if data_point['account_key'] not in udacity_test_accounts:
            non_udacity_data.append(data_point)
    return non_udacity_data

# %%
# Remove Udacity test accounts from all three tables
non_udacity_enrollments = remove_udacity_accounts(enrollments)
non_udacity_engagement = remove_udacity_accounts(daily_engagement)
non_udacity_submissions = remove_udacity_accounts(project_submissions)

print(len(non_udacity_enrollments))
print(len(non_udacity_engagement))
print(len(non_udacity_submissions))
# Out:
# 1622
# 135656
# 3634

# %% [markdown]
# ## Refining the Question

# %%
#####################################
#                 6                 #
#####################################

## Create a dictionary named paid_students containing all students who either
## haven't canceled yet or who remained enrolled for more than 7 days. The keys
## should be account keys, and the values should be the date the student enrolled.

paid_students = {}

for enrollment in non_udacity_enrollments:
    if not enrollment['is_canceled'] or enrollment['days_to_cancel'] > 7:
        account_key = enrollment['account_key']
        enrollment_date = enrollment['join_date']
        paid_students['account_key'] = enrollment_date

        if account_key not in paid_students or \
        enrollment_date > paid_students[account_key]:
            paid_students[account_key] = enrollment_date
            
len(paid_students)
# Out:
# 996

# %% [markdown]
# ## Getting Data from First Week

# %%
# Takes a student's join date and the date of a specific engagement record,
# and returns True if that engagement record happened within one week
# of the student joining.
def within_one_week(join_date, engagement_date):
    time_delta = engagement_date - join_date
    return time_delta.days < 7 and time_delta.days >= 0

# %%
def remove_free_trial_cancels(data):
    new_data = []
    for data_point in data:
        if data_point['account_key'] in paid_students:
            new_data.append(data_point)
    return new_data

# %%
paid_enrollments = remove_free_trial_cancels(non_udacity_enrollments)
paid_engagement = remove_free_trial_cancels(non_udacity_engagement)
paid_submissions = remove_free_trial_cancels(non_udacity_submissions)

print(len(paid_enrollments))
print(len(paid_engagement))
print(len(paid_submissions))
# Out:
# 1293
# 134549
# 3618

# %%
for engagement_record in paid_engagement:
    if engagement_record['num_courses_visited'] > 0:
        engagement_record['has_visited'] = 1
    else:
        engagement_record['has_visited'] = 0

# %%
#####################################
#                 7                 #
#####################################

## Create a list of rows from the engagement table including only rows where
## the student is one of the paid students you just found, and the date is within
## one week of the student's join date.

paid_engagement_in_first_week = []

for engagement_record in paid_engagement:
    #print(engagement_record)
    account_key = engagement_record['account_key']
    join_date = paid_students[account_key]
    engagement_record_date = engagement_record['utc_date']
    
    if within_one_week(join_date, engagement_record_date):
        paid_engagement_in_first_week.append(engagement_record)
        
len(paid_engagement_in_first_week)
# Out:
# 6919

# %% [markdown]
# ## Exploring Student Engagement

# %%
from collections import defaultdict

# Create a dictionary of engagement grouped by student.
# The keys are account keys, and the values are lists of engagement records.
engagement_by_account = defaultdict(list)

# print(engagement_by_account)

for engagement_record in paid_engagement_in_first_week:
    account_key = engagement_record['account_key']
    engagement_by_account[account_key].append(engagement_record)

# %%
# Create a dictionary with the total minutes each student spent in the classroom during the first week.
# The keys are account keys, and the values are numbers (total minutes)
total_minutes_by_account = {}
for account_key, engagement_for_student in engagement_by_account.items():
    total_minutes = 0
    for engagement_record in engagement_for_student:
        total_minutes += engagement_record['total_minutes_visited']
    total_minutes_by_account[account_key] = total_minutes

# %%
import numpy as np

def described_data(data):
    print('Mean:', np.mean(total_minutes))
    print('Standard deviation:', np.std(total_minutes))
    print('Minimum:', np.min(total_minutes)) 
    print('Maximum:', np.max(total_minutes))
    
# Summarize the data about minutes spent in the classroom
total_minutes = list(total_minutes_by_account.values())

described_data(total_minutes)
# Out:
# Mean: 306.708326753
# Standard deviation: 412.996933409
# Minimum: 0.0
# Maximum: 3564.7332645

# %% [markdown]
# ## Debugging Data Analysis Code

# %%
#####################################
#                 8                 #
#####################################

## Go through a similar process as before to see if there is a problem.
## Locate at least one surprising piece of data, output it, and take a look at it.
student_with_max_minutes = None
max_minutes = 0

for student, total_minutes in total_minutes_by_account.items():
    if total_minutes > max_minutes:
        max_minutes = total_minutes
        student_with_max_minutes = student
        
max_minutes
# Out:
# 3564.7332644989997

# %%
for engagement_record in paid_engagement_in_first_week:
    if engagement_record['account_key'] == student_with_max_minutes:
        print(engagement_record)
# Out:
# {'projects_completed': 0, 'num_courses_visited': 4, 'account_key': '163', 'utc_date': datetime.datetime(2015, 7, 9, 0, 0), 'total_minutes_visited': 850.519339666, 'lessons_completed': 4}
# {'projects_completed': 0, 'num_courses_visited': 6, 'account_key': '163', 'utc_date': datetime.datetime(2015, 7, 10, 0, 0), 'total_minutes_visited': 872.633923334, 'lessons_completed': 6}
# {'projects_completed': 0, 'num_courses_visited': 2, 'account_key': '163', 'utc_date': datetime.datetime(2015, 7, 11, 0, 0), 'total_minutes_visited': 777.018903666, 'lessons_completed': 6}
# {'projects_completed': 0, 'num_courses_visited': 1, 'account_key': '163', 'utc_date': datetime.datetime(2015, 7, 12, 0, 0), 'total_minutes_visited': 294.568774, 'lessons_completed': 2}
# {'projects_completed': 0, 'num_courses_visited': 3, 'account_key': '163', 'utc_date': datetime.datetime(2015, 7, 13, 0, 0), 'total_minutes_visited': 471.2139785, 'lessons_completed': 1}
# {'projects_completed': 0, 'num_courses_visited': 2, 'account_key': '163', 'utc_date': datetime.datetime(2015, 7, 14, 0, 0), 'total_minutes_visited': 298.778345333, 'lessons_completed': 1}
# {'projects_completed': 0, 'num_courses_visited': 0, 'account_key': '163', 'utc_date': datetime.datetime(2015, 7, 15, 0, 0), 'total_minutes_visited': 0.0, 'lessons_completed': 0}

# %% [markdown]
# ## Lessons Completed in First Week

# %%
#####################################
#                 9                 #
#####################################

## Adapt the code above to find the mean, standard deviation, minimum, and maximum for
## the number of lessons completed by each student during the first week. Try creating
## one or more functions to re-use the code above.
from collections import defaultdict

def group_data(data,key_name):
    grouped_data = defaultdict(list)
    for data_point in data:
        key = data_point[key_name]
        grouped_data[key].append(data_point)
    return grouped_data

engagement_by_account = group_data(paid_engagement_in_first_week,'account_key')

# %%
def sum_grouped_items(grouped_data, field_name):
    summed_data = {}
    
    for key,data_points in grouped_data.items():
        total = 0
        for data_point in data_points:
            total += data_point[field_name]
        summed_data[key] = total
    return summed_data

total_minutes_by_account = sum_grouped_items(engagement_by_account, 'total_minutes_visited')

# %% [markdown]
# ## Number of Visits in First Week

# %%
######################################
#                 10                 #
######################################

## Find the mean, standard deviation, minimum, and maximum for the number of
## days each student visits the classroom during the first week.
days_visited_by_account = sum_grouped_items(engagement_by_account,'has_visited')
described_data(days_visited_by_account)
# Out:
# Mean: 306.708326753
# Standard deviation: 412.996933409
# Minimum: 0.0
# Maximum: 3564.7332645

# %% [markdown]
# ## Splitting out Passing Students

# %%
######################################
#                 11                 #
######################################

## Create two lists of engagement data for paid students in the first week.
## The first list should contain data for students who eventually pass the
## subway project, and the second list should contain data for students
## who do not.

subway_project_lesson_keys = ['746169184', '3176718735']

pass_subway_project = set()

for submisssion in paid_submissions:
    project = submission['lesson_key']
    rating = submission['assigned_rating']
    
    if project in subway_project_lesson_keys and \
    (rating == 'PASSED' or rating == 'DISTINCTING'):
        pass_subway_project.add(submission['account_key'])

len(pass_subway_project)
# Out:
# 0

# %%
passing_engagement = []
non_passing_engagement = []

for engagement_record in paid_engagement_in_first_week:
    if engagement_record['account_key'] in pass_subway_project:
        passing_engagement.append(engagement_record)
    else:
        non_passing_engagement.append(engagement_record)
        
print(len(passing_engagement))
print(len(non_passing_engagement))
# Out:
# 0
# 6919

# %%
647
4527
2392

# %%
paid_submissions[0]
# Out:
# {'account_key': '256',
#  'assigned_rating': 'UNGRADED',
#  'completion_date': datetime.datetime(2015, 1, 16, 0, 0),
#  'creation_date': datetime.datetime(2015, 1, 14, 0, 0),
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %% [markdown]
# ## Comparing the Two Student Groups

# %%
######################################
#                 12                 #
######################################

## Compute some metrics you're interested in and see how they differ for
## students who pass the subway project vs. students who don't. A good
## starting point would be the metrics we looked at earlier (minutes spent
## in the classroom, lessons completed, and days visited).

# %% [markdown]
# ## Making Histograms

# %%
######################################
#                 13                 #
######################################

## Make histograms of the three metrics we looked at earlier for both
## students who passed the subway project and students who didn't. You
## might also want to make histograms of any other metrics you examined.

# %% [markdown]
# ## Improving Plots and Sharing Findings

# %%
######################################
#                 14                 #
######################################

## Make a more polished version of at least one of your visualizations
## from earlier. Try importing the seaborn library to make the visualization
## look better, adding axis labels and a title, and changing one or more
## arguments to the hist() function.
